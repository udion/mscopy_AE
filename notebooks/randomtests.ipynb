# %%
from scipy.ndimage.filters import gaussian_filter
import numpy as np
import scipy as sp
import PIL
from PIL import Image

# %%
t = Image.open('../sample_dataset/train/unlabeled/Normal_001_32902_91875_0_cropped_slide.png').convert('RGB')

# %%
tf = gaussian_filter(t, sigma=(10, 10, 0))

# %%
tf1 = Image.fromarray(tf)

# %%
tf1
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7EFCC0FA68D0>

# %%
t
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7EFCC2FB9F98>
