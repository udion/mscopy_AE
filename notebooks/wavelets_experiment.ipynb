# %%
import pywt
import numpy as np
import scipy as sp
import PIL
from PIL import Image

# %%
wavelet = pywt.DiscreteContinuousWavelet('db1')
print(wavelet)
# Out:
# Wavelet db1
#   Family name:    Daubechies
#   Short name:     db
#   Filters length: 2
#   Orthogonal:     True
#   Biorthogonal:   True
#   Symmetry:       asymmetric
#   DWT:            True
#   CWT:            False

# %%
#test image
test_img = PIL.Image.open('../sample_dataset/train/unlabeled/Tumor_036_22627_132294_1_cropped_slide.png').convert('RGB')
test_img_np = np.asarray(test_img, dtype=float)/255

# %%
coeffs=pywt.wavedec2(test_img_np, 'haar', level=1)

# %%
coeffs
# Out:
# [array([[[ 1.41764706,  1.5254902 ],
#          [ 1.93137255,  1.96862745],
#          [ 1.98235294,  1.97647059],
#          ...,
#          [ 1.99215686,  1.98431373],
#          [ 1.9627451 ,  1.96078431],
#          [ 1.50196078,  1.59607843]],
#
#         [[ 1.20392157,  1.3372549 ],
#          [ 1.84901961,  1.90196078],
#          [ 1.99607843,  1.99215686],
#          ...,
#          [ 1.99411765,  1.96470588],
#          [ 1.97058824,  1.94117647],
#          [ 1.52745098,  1.65098039]],
#
#         [[ 1.02156863,  1.15686275],
#          [ 1.69803922,  1.73333333],
#          [ 1.97254902,  1.98039216],
#          ...,
#          [ 1.98823529,  1.94509804],
#          [ 1.97254902,  1.94509804],
#          [ 1.54705882,  1.67843137]],
#
#         ...,
#         [[ 1.82156863,  1.83137255],
#          [ 1.73921569,  1.77254902],
#          [ 1.76470588,  1.79215686],
#          ...,
#          [ 1.18431373,  1.21568627],
#          [ 1.21764706,  1.21568627],
# ...
